# %%
import requests
import pandas as pd

# %%
#request API for Latest Covid-19 Data

# %%
response = requests.get('https://coronavirus.m.pipedream.net/')
response.status_code
# Out:
# 200

# %%
#Summary

# %%
response.json()
# Out:
# {'apiSourceCode': 'https://pipedream.com/@/p_G6CLVM',
#  'cache': {'expires': 'in 4 minutes',
#   'expiresTimestamp': 1633383761891,
#   'lastUpdated': 'a minute ago',
#   'lastUpdatedTimestamp': 1633383461891},
#  'dataSource': {'lastGithubCommit': '2021-10-04T16:37:26Z',
#   'publishedBy': 'John Hopkins University Center for Systems Science and Engineering',
#   'ref': 'https://github.com/CSSEGISandData/COVID-19',
#   'url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/10-03-2021.csv'},
#  'rawData': [{'Active': '',
#    'Admin2': '',
#    'Case_Fatality_Ratio': '4.6433105012532945',
#    'Combined_Key': 'Afghanistan',
#    'Confirmed': '155191',
#    'Country_Region': 'Afghanistan',
#    'Deaths': '7206',
#    'FIPS': '',
#    'Incident_Rate': '398.6581395801069',
#    'Last_Update': '2021-10-04 04:21:31',
#    'Lat': '33.93911',
#    'Long_': '67.709953',
#    'Province_State': '',
#    'Recovered': ''},
# ...

# %%
#Summary
